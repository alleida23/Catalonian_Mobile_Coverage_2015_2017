# %% [markdown]
# # Mastering SQL Queries with BigQuery: Data Exploration and Analysis

# %% [markdown]
# #### Introduction
#
# In this kernel, we embark on a journey of data exploration and analysis using the power of **BigQuery**, Google's cloud-based data warehouse. Our focus will be on **mastering SQL queries** to uncover valuable insights from complex datasets.
#
# This project delves into the **"Catalonian Mobile Coverage"** dataset, a rich source of information on mobile network coverage, operator activity, and user behavior. The primary dataset, **mobile_data_2015_2017_cleaned**, has undergone thorough cleaning and normalization in the previous kernel '1. SQL Data Cleaning for Mobile Coverage Dataset' to ensure data quality.

# %% [markdown]
# #### Key Data Sources:
#
#
# - **mobile_data_2015_2017_cleaned**, main dataset providing insights into mobile network coverage, operator activity, and user behavior.
#
# - **cat_percapita_income_by_province_2015_2017** and **cat_pop_by_province_2015_2017**, additional datasets supplying data on per capita income and population by province.

# %% [markdown]
# #### Prominent SQL Commands and Functions:
#
#    - **SQL SELECT Statements**: Querying data, filtering, sorting, and retrieving relevant information.
#    - **Grouping and Aggregation**: Summarizing data with COUNT, SUM, AVG, and more.
#    - **Window Functions**: Calculating rankings, tracking changes, and gaining insights.
#    - **Conditional Statements**: Categorizing data using CASE statements.
#    - **Subqueries**: Creating complex queries with embedded subqueries.
#    - **Views**: Organizing and filtering data for in-depth analysis.
#    - **Statistical Aggregate Functions**: Computing correlations, covariances, quartiles, and more.
#    - **Date Functions**: Exploring date ranges, identifying top activity dates, and analyzing monthly and hourly patterns.
#    - **Plotting and Visualization**: Presenting insights through interactive plots and visualizations.

# %% [markdown]
# #### Some Key Insights We Aim to Uncover:
#
# - Identifying the top net_provider in Catalonia with the highest activity recorded.
# - Finding the operator with the highest activity.
# - Determining which net_provider/operator combination exhibits the highest average signal strength.
# - Dividing operators into quartiles based on signal strength to assess performance variations.
# - Analyzing changes in signal strength and net_provider speed within specific nets.
# - Ranking net_provider and operators by record count and exploring the impact on rankings based on signal strength.

# %% [markdown]
# ## Import libraries and modules

# %%
import pandas as pd  # For data manipulation and analysis
from google.cloud import bigquery  # For interacting with Google BigQuery
from IPython.display import display  # For displaying data and results in Jupyter Notebook
from IPython.display import Markdown  # For displaying formatted Markdown content in Jupyter Notebook

# %% [markdown]
# ## Import functions

# %% [markdown]
# Import the custom **query_df** and **run_query** functions from the 'query_functions.py' file to execute SQL queries using a pre-configured BigQuery client object.

# %%
# Execute the query and return the output as a DataFrame
from query_functions import query_df  

# Execute the query without returning a DataFrame.
from query_functions import run_query

# %% [markdown]
# Import **styled_df_by_value** from styled_df_function to selectively highlight rows in DataFrames with specific values.

# %%
# Format DataFrame rows based on specified values
from styled_df_function import styled_df_by_value

# %% [markdown]
# _Note: The styling applied by 'styled_df_by_value' to highlight rows with specific values
# might not be visible when the DataFrame is displayed on GitHub due to GitHub's rendering limitations._

# %% [markdown]
# ## Preview datasets

# %% [markdown]
# ### Datasets paths

# %% [markdown]
# We are going to use shorter variables to store paths, aiming to enhance code readability and maintainability, particularly when performing queries.

# %%
# Catalonian mobile coverage (2015-2017)
mobile_data_cleaned = "bq-analyst-230590.project_cat_mobile_coverage_2015_2017.mobile_data_2015_2017_cleaned"

# Per capita income by catalan province (2015-2017)
percapita_income = "bq-analyst-230590.project_cat_mobile_coverage_2015_2017.cat_percapita_income_by_province_2015_2017"

# Catalan population and density by province (2015-2017)
pop_density = "bq-analyst-230590.project_cat_mobile_coverage_2015_2017.cat_pop_by_province_2015_2017"

# %% [markdown]
# ### Main dataset: mobile_data_cleaned

# %%
# SQL query:
query = f"""
    SELECT *
    FROM `{mobile_data_cleaned}`
    LIMIT 100
    """

# Execute the query and store the result
mob_data = query_df(query)

# Show table
display(mob_data.head(),mob_data.tail())
print("Shape: \n", mob_data.shape)
# Out:
#          date      hour       lat     long  signal net_provider operator  \
# 0  2015-09-09  16:27:40  42.13125  3.10146      10           EE       EE
# 1  2015-09-05  21:39:07  42.41991  2.87064       8           EE       EE
# 2  2015-09-09  18:19:04  42.02296  2.81729      12           EE       EE
# 3  2015-09-08  17:52:49  41.80524  2.77934      14           EE       EE
# 4  2015-09-08  13:35:17  41.80413  2.75962       8           EE       EE
#
#             description net  speed  satellites  precision position_provider  \
# 0  STATE_EMERGENCY_ONLY  4G   71.1         8.0       16.0               GPS
# 1  STATE_EMERGENCY_ONLY  3G  113.4         1.0       21.0               GPS
# 2  STATE_EMERGENCY_ONLY  4G  129.6         5.0       26.0               GPS
# 3  STATE_EMERGENCY_ONLY  2G    3.5        10.0       11.0               GPS
# 4  STATE_EMERGENCY_ONLY  2G   76.9         2.0       11.0               GPS
#
# ...

# %%
# Column types
mob_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               100 non-null    object
#  1   hour               100 non-null    object
#  2   lat                100 non-null    float64
#  3   long               100 non-null    float64
#  4   signal             100 non-null    int64
#  5   net_provider       100 non-null    object
#  6   operator           100 non-null    object
#  7   description        100 non-null    object
#  8   net                100 non-null    object
#  9   speed              100 non-null    float64
#  10  satellites         100 non-null    float64
#  11  precision          100 non-null    float64
#  12  position_provider  100 non-null    object
#  13  activity           100 non-null    object
#  14  postal_code        100 non-null    object
#  15  town_name          100 non-null    object
# ...

# %% [markdown]
# ### Additional datasets: percapita_income & pop_density

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL query: Display both tables joined
query = f"""
SELECT
     -- Columns from 'percapita_income' c table
    c.year,
    c.province,
    c.per_capita_income,
     -- Columns from 'pop_density' p table
    p.population,
    p.sq_km,
    p.density_per_sq_km,
FROM `{percapita_income}` c
JOIN `{pop_density}` p
    ON c.year = p.year AND c.province = p.province
ORDER BY 2 DESC, 1 DESC
    """

# Execute the query
query_df(query)
# Out:
#     year   province  per_capita_income  population  sq_km  density_per_sq_km
# 0   2017  Tarragona              23534      810600   6303              128.6
# 1   2016  Tarragona              23130      810947   6303              128.7
# 2   2015  Tarragona              22486      811089   6303              128.7
# 3   2017     Lleida              21091      741884  12172               61.0
# 4   2016     Lleida              20713      742099  12172               61.0
# 5   2015     Lleida              20136      742138  12172               61.0
# 6   2017     Girona              25992      766705   5908              129.8
# 7   2016     Girona              25598      766273   5908              129.7
# 8   2015     Girona              25200      765783   5908              129.6
# 9   2017  Barcelona              28481     5652301   7726              731.6
# 10  2016  Barcelona              27913     5635085   7726              729.4
# ...

# %% [markdown]
# ## Execute queries:

# %% [markdown]
# **1. Filtering and Sorting**
#
# **2. Aggregation**
#
# **3. SQL Joins: A Variety of Techniques**
#
# **4. Case Statements**
#
# **5. Statistical Aggregate Functions**
#
# **6. Window Functions**
#
# **7. Datetime Functions & Visualization**
#
# **8. Extra Queries & Visualization**

# %% [markdown]
# ### 1. Filtering and Sorting

# %% [markdown]
# **1.1. Retrieve all records from the '{mobile_data_cleaned}' table for the year 2016 where the 'signal' strength is above a threshold of 50 and 'net' is not 'Undefined net'.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, AND, ORDER BY, DESC, LIMIT
# - **Operators**: =, >, !=

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT 
        year,
        operator,
        net,
        signal
    FROM `{mobile_data_cleaned}`
    WHERE 
        year = 2016
        AND signal > 50
        AND NET != 'Undefined net'
    ORDER BY signal DESC
    LIMIT 1000
    """

# Execute the query
query_df(query)
# Out:
#      year  operator net  signal
# 0    2016  Movistar  2G      99
# 1    2016   Jazztel  3G      99
# 2    2016  Movistar  3G      99
# 3    2016  Movistar  2G      99
# 4    2016  Movistar  3G      99
# ..    ...       ...  ..     ...
# 995  2016  Vodafone  4G      65
# 996  2016  Movistar  4G      65
# 997  2016  Movistar  4G      65
# 998  2016     Yoigo  4G      65
# 999  2016    Orange  4G      65
#
# [1000 rows x 4 columns]

# %% [markdown]
# **1.2. Retrieve records from the '{mobile_data_cleaned}' table for:**
#
#  **- The year 2017 where 'net' is '4G' and 'description' is 'STATE_IN_SERVICE' and 'speed' is above 100.**
#
#  **- The year 2016 where 'net' is '3G' and 'signal' strength exceeds the year's average '3G' signal strength.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, OR, AND, ORDER BY, LIMIT
# - **Aggregated Funtions**: AVG()
# - **Operators**: =, >
# - **Subqueries**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      year,
      operator,
      net,
      description,
      signal,
      speed
    FROM `{mobile_data_cleaned}`
    WHERE
        -- Select records for '4G' net in 2017 with STATE_IN_SERVICE description and speed > 100.0
      (year = 2017
      AND net = '4G'
      AND description = 'STATE_IN_SERVICE'
      AND speed > 100.0)
      OR
        -- Select records for 3G network in 2016 with signal greater than the average signal strength for '3G' records in 2016
      (year = 2016
      AND net = '3G'
      AND signal > (
      
           -- Subquery to calculate average signal strength for '3G' records in 2016
          SELECT
              AVG(signal)
          FROM `{mobile_data_cleaned}`
          WHERE
              year = 2016
              AND net = '3G')
       )
    ORDER BY 1 DESC
    LIMIT 1000;
    """
# Execute the query
query_df(query)
# Out:
#      year  operator net           description  signal  speed
# 0    2017    Orange  4G      STATE_IN_SERVICE      21  103.4
# 1    2017  Vodafone  4G      STATE_IN_SERVICE      17  113.9
# 2    2017   Jazztel  4G      STATE_IN_SERVICE       4  108.2
# 3    2017  Vodafone  4G      STATE_IN_SERVICE      18  101.3
# 4    2017  Vodafone  4G      STATE_IN_SERVICE       7  100.3
# ..    ...       ...  ..                   ...     ...    ...
# 995  2016     Yoigo  3G  STATE_EMERGENCY_ONLY      17    9.0
# 996  2016      RACC  3G  STATE_EMERGENCY_ONLY      15  127.7
# 997  2016      RACC  3G  STATE_EMERGENCY_ONLY      14    6.0
# 998  2016     Yoigo  3G  STATE_EMERGENCY_ONLY      14   92.0
# 999  2016     Yoigo  3G  STATE_EMERGENCY_ONLY      14    0.0
#
# [1000 rows x 6 columns]

# %% [markdown]
# **1.3. Calculate and display the top 3 Orange 'operators' with the highest 'activity count' for the '4G' category, for both the years 2017 and 2016. Organize the results by the number of 'activity counts' in descending order and present the findings.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, WHERE, AND, GROUP BY, ORDER BY, DESC
# - **Aggregated Functions**: COUNT()
# - **Set Operations**: UNION ALL
# - **Operators**: =
# - **CTEs**: OrangeOperators_4G_2017, OrangeOperators_4G_2016

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
 -- Common Table Expression (CTE): Top-3 activity count '4G' Orange Operator in 2017
WITH OrangeOperators_4G_2017 AS ( 
    SELECT
        year,
        net,
        operator,
        COUNT(*) activity_count
    FROM `{mobile_data_cleaned}`
    WHERE
      net_provider = 'Orange'
      AND net = '4G'
      AND year = 2017
    GROUP BY 1,2,3 
    ORDER BY 1 DESC, 2 DESC, 4 DESC
    LIMIT 3
    ),
    
     -- CTE: Top-3 activity count '4G' Orange Operator in 2016
    OrangeOperators_4G_2016 AS ( 
    SELECT
        year,
        net,
        operator,
        COUNT(*) activity_count
    FROM `{mobile_data_cleaned}`
    WHERE
      net_provider = 'Orange'
      AND net = '4G'
      AND year = 2016
    GROUP BY 1,2,3 
    ORDER BY 1 DESC, 2 DESC, 4 DESC
    LIMIT 3
    )

SELECT
    year,
    net,
    operator,
    activity_count
FROM `OrangeOperators_4G_2017`
UNION ALL
SELECT
    year,
    net,
    operator,
    activity_count
FROM `OrangeOperators_4G_2016`
ORDER BY 1 DESC, 4 DESC
    """
# Execute the query
query_df(query)
# Out:
#    year net operator  activity_count
# 0  2017  4G   Orange          173994
# 1  2017  4G    adamo           13295
# 2  2017  4G  Jazztel           11513
# 3  2016  4G   Orange          533644
# 4  2016  4G  Jazztel          108857
# 5  2016  4G    Simyo           15286

# %% [markdown]
# **1.4. Calculate the percentage of records where the activity is 'IN_VEHICLE' and 'net' is NOT 'Undefined net' in the '{mobile_data_cleaned}' table for the year 2017.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, AND, GROUP BY
# - **Aggregated Functions**: COUNT()
# - **Mathematical Functions**: ROUND()
# - **Operators**: /, =, !=
# - **Subqueries**: in_vehicle_subquery, total_subquery

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
SELECT
    net,
    ROUND((in_vehicle_2017_count / total_count * 100), 2) AS in_vehicle_2017_perc
FROM (
        -- Subquery to calculate the count of records GROUPED BY 'net'      
    SELECT 
        net,
        COUNT(*) AS in_vehicle_2017_count
    FROM `{mobile_data_cleaned}`
    WHERE year = 2017
        AND activity = 'IN_VEHICLE'
        AND net != 'Undefined net'
    GROUP BY 1
    ) in_vehicle_subquery,
    
        -- Subquery to calculate the total count of records.
    (
     SELECT COUNT(*) AS total_count
     FROM `{mobile_data_cleaned}`
     WHERE year = 2017
        AND activity = 'IN_VEHICLE'
        AND net != 'Undefined net'
    ) total_subquery
    """
# Execute the query
query_df(query)
# Out:
#   net  in_vehicle_2017_perc
# 0  4G                 57.83
# 1  3G                 26.18
# 2  2G                 15.99

# %% [markdown]
# ### 2. Aggregation

# %% [markdown]
# **2.1. Calculate the count, average, standard deviation, minimum, and maximum speed for each province in Catalonia with a population density of less than 130 inhabitants per square kilometer and a name containing 'ona'. What are the speed statistics for these provinces?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, GROUP BY, HAVING
# - **Aggregated Functions**: COUNT(), ROUND(), MIN(), MAX()
# - **Statistical Functions**: STDDEV_POP()
# - **String Functions**: REGEXP_CONTAINS()
# - **Operators**: =, <
# - **Joins**: JOIN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
        m.province,
        COUNT(m.speed) speed_counts,
        ROUND(AVG(m.speed),2) avg_speed,
        ROUND(STDDEV_POP(m.speed),2) std_speed,
        MIN(m.speed) min_speed,
        MAX(m.speed) max_speed
    FROM `{mobile_data_cleaned}` m
    JOIN `{pop_density}` p
     ON m.province = p.province
    WHERE p.density_per_sq_km < 130 # This would include 'Girona', 'Tarragona' and 'Lleida'
    GROUP BY 1
     -- Use of REGEXP_CONTAINS() to find 'ona' pattern in 'province' column names
     HAVING REGEXP_CONTAINS(m.province, 'ona') # This would include 'Barcelona', 'Girona' and 'Tarragona'
    """
# Execute the query
query_df(query)
# Out:
#     province  speed_counts  avg_speed  std_speed  min_speed  max_speed
# 0     Girona       4128609      26.64      34.75        0.0      255.0
# 1  Tarragona       2974152      27.76      37.08        0.0      254.9

# %% [markdown]
# **2.2. For net_providers with multiple operators, find the total, maximum, and average number of satellites used by each unique pair of network providers (net_provider) and operators (operator).**
#
# **Provide the total satellites usage, maximum satellites usage within a single activity, and average satellites usage in the result for these specific network providers.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses:** SELECT, FROM, WHERE, GROUP BY, HAVING, ORDER BY
# - **Aggregated Functions:** SUM(), MAX(), AVG(), COUNT(), DISTINCT()
# - **Conversion Functions:** CAST()
# - **String Functions:** CONCAT()
# - **Operators:** >
# - **Subqueries:** unique_pairs_subquery

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
SELECT
 netprovider_operator,
 total_satellites_usage,
 max_satellites_per_record,
 avg_satellites_per_record
FROM (
     -- Create unique pairs of net_provider + operator...
    SELECT
        CONCAT(net_provider, ' - ', operator) AS netprovider_operator,
        CAST(SUM(satellites) AS INT64) AS total_satellites_usage,
        CAST(MAX(satellites) AS INT64) AS max_satellites_per_record,
        CAST(AVG(satellites) AS INT64) AS avg_satellites_per_record
    FROM `{mobile_data_cleaned}`
    WHERE net_provider IN (
            
         -- ... only if the net_provider has multiple operators
        SELECT net_provider
        FROM `{mobile_data_cleaned}`
        GROUP BY net_provider
        HAVING COUNT(DISTINCT operator) > 1
        )
    GROUP BY 1
) AS unique_pairs_subquery
ORDER BY total_satellites_usage DESC, max_satellites_per_record DESC
    """

# Execute the query
query_df(query)
# Out:
#      netprovider_operator  total_satellites_usage  max_satellites_per_record  \
# 0     Movistar - Movistar                21025335                         42
# 1     Vodafone - Vodafone                13025235                         29
# 2         Orange - Orange                 9709569                         29
# 3        Orange - Jazztel                 2369254                         26
# 4    Movistar - Pepephone                 1850320                         25
# 5          Orange - Simyo                  615420                         25
# 6           Orange - RACC                  586762                         25
# 7       Movistar - Tuenti                  214929                         22
# 8         Orange - PARLEM                  207948                         22
# 9          Movistar - ONO                  196699                         20
# 10         Orange - adamo                  117981                         21
# ...

# %% [markdown]
# **2.3. Find the first recorded activity in terms of date and hour for each province. Include the date, hour, and net_provider columns in the result.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, IS NOT NULL, ORDER BY, ASC
#
# - **Operators:** =
#
# - **Subqueries**: ranked_data
#
# - **Window Functions**: ROW_NUMBER()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
        province,
        date,
        hour,
        net_provider AS first_net_provider
    FROM (
         -- Subquery to assign a row number to each record based on the order of 'date' and 'hour' within each 'province'
        SELECT
            date,
            hour,
            net_provider,
            province,
             -- The ROW_NUMBER() function partitions data by 'province,' arranging it chronologically and assigns sequential 
             -- numbers to rows within each province.
            ROW_NUMBER() OVER (PARTITION BY province ORDER BY date, hour) AS row_num
        FROM `{mobile_data_cleaned}`
        WHERE net_provider IS NOT NULL
    ) ranked_data
     -- Selects records with row numbers equal to 1 (the earliest recorded activity for each 'province')
    WHERE row_num = 1
    ORDER BY date ASC
    """

# Execute the query
query_df(query)
# Out:
#     province        date      hour first_net_provider
# 0  Barcelona  2015-01-05  00:48:37           Vodafone
# 1  Tarragona  2015-01-15  16:56:58           Vodafone
# 2     Girona  2015-01-25  11:45:18           Vodafone
# 3     Lleida  2015-01-29  10:58:50           Vodafone

# %% [markdown]
# ### 3. SQL Joins: A Variety of Techniques

# %% [markdown]
# **3.1. Join the '{mobile_data_cleaned}' table with the '{pop_density}' and the '{pop_density}' tables to retrieve records from all tables for the year 2016 and calculate the average signal strength (signal) for each 'province'.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, AND, GROUP BY, ORDER BY, DESC
# - **Aggregated Functions**: AVG()
# - **Mathematical Functions**: ROUND()
# - **Operators:** =
# - **Joins**: JOIN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT 
      m.province,
      p.sq_km,
      p.population AS population_2016,
      p.density_per_sq_km AS pop_density_2016,
      c.per_capita_income AS per_capita_inc_2016,
      ROUND(AVG(m.signal),2) avg_signal_2016
    FROM `{mobile_data_cleaned}` m
    JOIN `{pop_density}` p 
      ON m.province = p.province AND m.year = p.year
    JOIN `{percapita_income}` c
      ON m.province = c.province AND m.year = c.year
    WHERE m.year = 2016
    GROUP BY 1,2,3,4,5
    ORDER BY 6 DESC;
    """

# Execute the query
query_df(query)
# Out:
#     province  sq_km  population_2016  pop_density_2016  per_capita_inc_2016  \
# 0  Barcelona   7726          5635085             729.4                27913
# 1     Lleida  12172           742099              61.0                20713
# 2  Tarragona   6303           810947             128.7                23130
# 3     Girona   5908           766273             129.7                25598
#
#    avg_signal_2016
# 0            13.38
# 1            12.83
# 2            12.69
# 3            11.95

# %% [markdown]
# **3.2. Calculate the average signal strength (signal) and average monthly activity for each month using data from the dataset {mobile_data_cleaned}, and order the results in descending order based on the average monthly activity.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, WITH, FROM, GROUP BY, ORDER BY, DESC
# - **Aggregated Functions**: COUNT(), AVG()
# - **Date Functions**: EXTRACT()
# - **Mathematical Functions**: ROUND()
# - **Operators**: =, *, /
# - **CTEs**: MonthlyActivity, PercentTotalActivity
# - **Joins**: JOIN, CROSS JOIN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
     -- CTE: Calculate monthly registered activity and average signal
    WITH MonthlyActivity AS (
        SELECT
            EXTRACT(MONTH FROM date) as month,
            COUNT(*) AS monthly_activity,
            ROUND(AVG(signal), 2) as avg_signal
        FROM `{mobile_data_cleaned}`
        GROUP BY 1
    ),

     -- CTE: Calculate the percentage of monthly activity for the total annual activity
    PercentTotalActivity AS (
        SELECT
            ma.month,
            ROUND((ma.monthly_activity / t.total_activity),2) * 100 as perc_total_activity
        FROM MonthlyActivity ma
        CROSS JOIN (
        
             -- The CROSS JOIN combines the row count from 'MonthlyActivity' with the total record count 
             -- to compute annual activity. This links each monthly count with the overall record count        
        
            SELECT
                COUNT(*) AS total_activity
            FROM `{mobile_data_cleaned}`
        ) t
    )

    SELECT 
        ma.month,
        pta.perc_total_activity,
        ROUND(AVG(ma.monthly_activity), 2) AS avg_monthly_activity,
        ma.avg_signal
    FROM MonthlyActivity ma
    JOIN PercentTotalActivity pta
     ON ma.month = pta.month
    GROUP BY 1, 2, 4
    ORDER BY 3 DESC
    """

# Execute the corrected query
query_df(query)
# Out:
#     month  perc_total_activity  avg_monthly_activity  avg_signal
# 0       9                 10.0             1065753.0       13.14
# 1       5                 10.0             1037712.0       13.21
# 2       6                  9.0              990234.0       13.06
# 3       3                  9.0              968422.0       13.34
# 4      10                  9.0              925787.0       13.32
# 5       7                  9.0              915300.0       13.08
# 6       8                  8.0              872794.0       12.75
# 7      12                  8.0              865982.0       13.27
# 8      11                  8.0              857949.0       13.31
# 9       4                  8.0              813640.0       13.62
# 10      1                  6.0              690627.0       13.24
# 11      2                  6.0              651213.0       13.36

# %% [markdown]
# **3.3. Retrieve the total population and average per capita income for Catalonia for the years 2015, 2016, and 2017, along with their respective population growth and per capita income growth rates.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WITH, ORDER BY, ASC, DESC
# - **Conditional Functions**: IFNULL()
# - **Conversion Functions**: CAST()
# - **Math Functions**: ROUND(), SUM()
# - **Operators:** =, -, /, *
# - **CTEs**: TotalCatalanPopulation, AveragePerCapitaIncome
# - **Joins**: LEFT JOIN, JOIN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
 -- CTE: Calculate annual population in Catalunya
WITH TotalCatalanPopulation AS (
    SELECT
        year,
        SUM(population) total_population
    FROM `{pop_density}`
    GROUP BY 1
    ORDER BY 1 ASC
),
 -- CTE: Calculate the average per capita income in Catalunya
AveragePerCapitaIncome AS (
    SELECT
        year,
        AVG(per_capita_income) avg_per_capita_income
    FROM `{percapita_income}`
    GROUP BY 1
    ORDER BY 1 ASC
)

SELECT
 p1.year,
 p1.total_population,
  -- Calculate annual population growth
 IFNULL(
     CAST(ROUND(((p1.total_population - p2.total_population) / p2.total_population * 100), 2) AS STRING),'No data'
    ) AS pop_growth,
 c1.avg_per_capita_income,
  -- Calculate annual per capita income growth
 IFNULL(
     CAST(ROUND(((c1.avg_per_capita_income - c2.avg_per_capita_income) / c2.avg_per_capita_income * 100), 2) AS STRING),'-'
    ) AS percapita_income_growth
FROM `TotalCatalanPopulation` p1

 -- LEFT JOIN to connect p1 (current year) to p2 ('+1' next year) to calculate the growth rates.
 -- This ensures all available data for the subsequent year (p2) is considered.

LEFT JOIN `TotalCatalanPopulation` p2
    ON p1.year = p2.year + 1
JOIN `AveragePerCapitaIncome` c1
    ON p1.year = c1.year
LEFT JOIN `AveragePerCapitaIncome` c2
    ON c1.year = c2.year + 1
ORDER BY 1 DESC
"""

# Execute the query
query_df(query)
# Out:
#    year  total_population pop_growth  avg_per_capita_income  \
# 0  2017           7971490       0.21                24774.5
# 1  2016           7954404       0.22                24338.5
# 2  2015           7937172    No data                23759.0
#
#   percapita_income_growth
# 0                    1.79
# 1                    2.44
# 2                       -

# %% [markdown]
# _As there is no population or per capita income data available for 2014, we use the `CAST` function to convert the numeric result of the growth calculation to a string. This ensures that the 'No data' placeholder, which is a string, can be used consistently in the result. Without the `CAST`, there could be a data type mismatch in the `IFNULL` function,
# which requires consistent data types for its arguments, ensuring that 'No data' is returned when data is missing._

# %% [markdown]
# **3.4. Explore the annual performance trends for key indicators such as average signal strength, population, and per capita income across the provinces of Barcelona, Girona, Lleida, and Tarragona for the years 2016 and 2017.**

# %% [markdown]
# **SQL Query Structure and Functions Guidelines:**
#
# - **Clauses**: SELECT, FROM, WITH, ORDER BY, ASC, DESC
# - **Aggregate Functions**: COUNT(), AVG()
# - **Math Functions**: ROUND()
# - **Operators:** =, -, /, *
# - **CTEs**: annual_data
# - **Joins**: JOIN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
 -- CTE: Retrieve the data for each year and province
WITH annual_data AS (
    SELECT
        m.year,
        m.province,
        ROUND(AVG(m.signal), 2) avg_signal,
        COUNT(*) activity_count,
        p.population,
        c.per_capita_income
    FROM `{mobile_data_cleaned}` m
    JOIN `{pop_density}` p
        ON m.province = p.province AND m.year = p.year
    JOIN `{percapita_income}` c
        ON m.province = c.province AND m.year = c.year
    GROUP BY 1, 2, 5, 6
    ORDER BY 2 ASC, 1 DESC
)

 -- Calculate annual growth percentages for each feature and province
SELECT
    a1.year,
    a1.province,
    a1.avg_signal,
     -- Calculate Average Signal Growth
    ROUND((a1.avg_signal - a2.avg_signal) / a2.avg_signal * 100, 2) AS avg_signal_growth,
     -- Calculate Activity Count Growth
    ROUND((a1.activity_count - a2.activity_count) / a2.activity_count * 100, 2) AS activity_count_growth,
     -- Calculate Population Growth
    ROUND((a1.population - a2.population) / a2.population * 100, 2) AS population_growth,
     -- Calculate Per Capita Income Growth
    ROUND((a1.per_capita_income - a2.per_capita_income) / a2.per_capita_income * 100, 2) AS per_capita_income_growth
FROM annual_data a1

 -- Join the 'annual_data' a2 to compare data for the same province and the next year (a2.year +1)
JOIN annual_data a2
    ON a1.province = a2.province
     -- Compare data for the current year with data from the next year
    AND a1.year = a2.year + 1 
ORDER BY a1.province ASC, a1.year DESC
"""

# Execute the query
query_df(query)
# Out:
#    year   province  avg_signal  avg_signal_growth  activity_count_growth  \
# 0  2017  Barcelona       12.86              -3.89                 -53.96
# 1  2016  Barcelona       13.38              -5.77                   9.88
# 2  2017     Girona       11.92              -0.25                 -51.11
# 3  2016     Girona       11.95              -1.89                  -0.50
# 4  2017     Lleida       11.81              -7.95                 -46.45
# 5  2016     Lleida       12.83               2.72                 -31.01
# 6  2017  Tarragona       12.96               2.13                 -39.88
# 7  2016  Tarragona       12.69              -1.17                 -18.64
#
#    population_growth  per_capita_income_growth
# 0               0.31                      2.03
# 1               0.30                      2.57
# 2               0.06                      1.54
# 3               0.06                      1.58
# 4              -0.03                      1.82
# ...

# %% [markdown]
#     - Check and compare annual activity_count (focus on high negative activity count growth in 2017)

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
SELECT
    year,
    COUNT(*) annual_activity_count
FROM `{mobile_data_cleaned}`
GROUP BY 1
ORDER BY 1 DESC
"""

# Execute the query
query_df(query)
# Out:
#    year  annual_activity_count
# 0  2017                2075215
# 1  2016                4311543
# 2  2015                4268655

# %% [markdown]
#     - Annual activity counts for the year 2017 show significantly fewer records compared to 2016 and 2015, which explains the negative growth observed in the previous query.

# %% [markdown]
# **3.5. We will now introduce simulated missing data into the 'pop_density' table by adding rows with NULL or different values in some of its columns, causing it to not perfectly align with the values in 'mobile_data_cleaned'.**
#
# **This step enables us to observe the outcomes resulting from various types of joins (LEFT, RIGHT, INNER, FULL). Following this, a series of join operations will be performed to analyze the diverse outputs generated.**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: Insert new (incomplete) data into 'pop_density' table
query = f"""
    INSERT INTO `{pop_density}`(year, population, sq_km)
    VALUES 
        (2015, 600000, 500),
        (2014, 530000, 490),
        (2016, 420000, 400),
        (2017, 385000, 380);
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: Insert more new (incomplete) data into 'pop_density' table
query = f"""   
    INSERT INTO `{pop_density}`(province, year, sq_km)
    VALUES
        ('Costa Brava', 2017, 678),
        ('Pirineus', 2015, 10000);
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: check new output
query = f"""
    SELECT *
    FROM `{pop_density}`;
    
    """

# Execute the query
query_df(query)
# Out:
#        province  year  population  sq_km  density_per_sq_km
# 0        Girona  2016    766273.0   5908              129.7
# 1        Girona  2017    766705.0   5908              129.8
# 2        Girona  2015    765783.0   5908              129.6
# 3        Lleida  2015    742138.0  12172               61.0
# 4        Lleida  2016    742099.0  12172               61.0
# 5        Lleida  2017    741884.0  12172               61.0
# 6     Barcelona  2015   5618162.0   7726              727.2
# 7     Barcelona  2016   5635085.0   7726              729.4
# 8     Barcelona  2017   5652301.0   7726              731.6
# 9     Tarragona  2015    811089.0   6303              128.7
# 10    Tarragona  2016    810947.0   6303              128.7
# 11    Tarragona  2017    810600.0   6303              128.6
# 12     Pirineus  2015         NaN  10000                NaN
# 13  Costa Brava  2017         NaN    678                NaN
# 14         None  2016    420000.0    400                NaN
# ...

# %% [markdown]
# **3.5.1. FULL (OUTER) JOIN: Find matching and unique provinces between tables**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
SELECT 
    prov_pop_dens, 
    prov_mob_data_cle
FROM (
     -- Select unique 'province' values in 'pop_density' table
    SELECT DISTINCT province AS prov_pop_dens
    FROM `{pop_density}`
) AS p
FULL OUTER JOIN (
     -- Select unique 'province' values in 'mobile_data_cleaned' table
    SELECT DISTINCT province AS prov_mob_data_cle
    FROM `{mobile_data_cleaned}`
    ) AS m 
    ON p.prov_pop_dens = m.prov_mob_data_cle
ORDER BY 1 ASC
    """

# Execute the query
query_df(query)
# Out:
#   prov_pop_dens prov_mob_data_cle
# 0          None              None
# 1     Barcelona         Barcelona
# 2   Costa Brava              None
# 3        Girona            Girona
# 4        Lleida            Lleida
# 5      Pirineus              None
# 6     Tarragona         Tarragona

# %% [markdown]
# This **FULL OUTER JOIN** or **FULL JOIN** shows all unique provinces from both tables, and in cases where a province exists in only one table, it pairs the corresponding entry with None in the other table to represent the absence of a matching province. This output illustrates the common and unique provinces between the two datasets.

# %% [markdown]
# **3.5.2. LEFT JOIN: Count the number of records for each province and year, using 'mobile_data_cleaned' as the left table and 'pop_density'**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      p.province,
      p.year,
      COUNT(m.signal) activity_count
    FROM `{mobile_data_cleaned}` m
    LEFT JOIN `{pop_density}` p
        ON p.province = m.province AND p.year = m.year
    GROUP BY 1,2
    ORDER BY 1,2 DESC;
    """

# Execute the query
query_df(query)
# Out:
#      province  year  activity_count
# 0   Barcelona  2017         1415583
# 1   Barcelona  2016         3074699
# 2   Barcelona  2015         2798357
# 3      Girona  2017          269793
# 4      Girona  2016          551816
# 5      Girona  2015          554594
# 6      Lleida  2017          179247
# 7      Lleida  2016          334745
# 8      Lleida  2015          485195
# 9   Tarragona  2017          210592
# 10  Tarragona  2016          350283
# 11  Tarragona  2015          430509

# %% [markdown]
# The **LEFT JOIN** ensures that all records from the **left table (mobile_data_cleaned)** are retained in the output. It incorporates matches from the **right table (pop_density)** where available, while not displaying unmatched entries from the right table (for instance, None, Pirineus, Costa Brava and 2014 in this case).
#
# In scenarios where the left table contains more 'provinces' or 'years' than the right table, unmatched entries from the right table would be filled with null or NaN values in the output.

# %% [markdown]
# **3.5.3. RIGHT JOIN: What is the average signal and maximum speed for each province and year, emphasizing 'pop_density' inclusion?**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      p.province,
      p.year,
      ROUND(AVG(m.signal),2) avg_signal,
      ROUND(MAX(m.speed),2) max_speed
    FROM `{mobile_data_cleaned}` m
    RIGHT JOIN `{pop_density}` p
        ON m.province = p.province AND m.year = p.year
    GROUP BY 1,2
    ORDER BY 1,2 DESC;
    """

# Execute the query
query_df(query)
# Out:
#        province  year  avg_signal  max_speed
# 0          None  2017         NaN        NaN
# 1          None  2016         NaN        NaN
# 2          None  2015         NaN        NaN
# 3          None  2014         NaN        NaN
# 4     Barcelona  2017       12.86      254.8
# 5     Barcelona  2016       13.38      255.0
# 6     Barcelona  2015       14.20      255.0
# 7   Costa Brava  2017         NaN        NaN
# 8        Girona  2017       11.92      253.9
# 9        Girona  2016       11.95      255.0
# 10       Girona  2015       12.18      254.9
# 11       Lleida  2017       11.81      254.9
# 12       Lleida  2016       12.83      254.6
# 13       Lleida  2015       12.49      254.8
# 14     Pirineus  2015         NaN        NaN
# 15    Tarragona  2017       12.96      254.9
# 16    Tarragona  2016       12.69      254.3
# 17    Tarragona  2015       12.84      254.9

# %% [markdown]
# A **RIGHT JOIN** ensures that all records from the **right table (pop_density)** are included, and matches from the **left table (mobile_data_cleaned)** are added where they exist. The None or NaN values in the output represent instances where provinces and years exist in the right table (in this case, None, Pirineus and Costa Brava and 2014) but don’t have corresponding matches in the left table, based on the specified conditions in the join.

# %% [markdown]
# **3.5.4. INNER JOIN: Calculate the average signal strength and maximum speed by matching province and year of both tables.**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      p.province,
      p.year,
      ROUND(AVG(m.signal),2) avg_signal,
      ROUND(MAX(m.speed),2) max_speed
    FROM `{pop_density}` p
    INNER JOIN `{mobile_data_cleaned}` m
        ON p.province = m.province AND p.year = m.year
    GROUP BY 1,2
    ORDER BY 1,2 DESC;
    """

# Execute the query
query_df(query)
# Out:
#      province  year  avg_signal  max_speed
# 0   Barcelona  2017       12.86      254.8
# 1   Barcelona  2016       13.38      255.0
# 2   Barcelona  2015       14.20      255.0
# 3      Girona  2017       11.92      253.9
# 4      Girona  2016       11.95      255.0
# 5      Girona  2015       12.18      254.9
# 6      Lleida  2017       11.81      254.9
# 7      Lleida  2016       12.83      254.6
# 8      Lleida  2015       12.49      254.8
# 9   Tarragona  2017       12.96      254.9
# 10  Tarragona  2016       12.69      254.3
# 11  Tarragona  2015       12.84      254.9

# %% [markdown]
# An **INNER JOIN** retrieves only the rows from both tables that have matching values based on the specified join condition (p.province = m.province AND p.year = m.year).  Records where there are no matches based on the specified join condition are excluded from the result set.

# %% [markdown]
# **3.5.5. FULL JOIN: Calculate the average signal strength and maximum speed, merging province and year from both tables.**

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      p.province,
      p.year,
      ROUND(AVG(m.signal),2) avg_signal,
      ROUND(MAX(m.speed),2) max_speed
    FROM `{pop_density}` p
    FULL JOIN `{mobile_data_cleaned}` m
        ON p.province = m.province AND p.year = m.year
    GROUP BY 1,2
    ORDER BY 1,2 DESC;
    """

# Execute the query
query_df(query)
# Out:
#        province  year  avg_signal  max_speed
# 0          None  2017         NaN        NaN
# 1          None  2016         NaN        NaN
# 2          None  2015         NaN        NaN
# 3          None  2014         NaN        NaN
# 4     Barcelona  2017       12.86      254.8
# 5     Barcelona  2016       13.38      255.0
# 6     Barcelona  2015       14.20      255.0
# 7   Costa Brava  2017         NaN        NaN
# 8        Girona  2017       11.92      253.9
# 9        Girona  2016       11.95      255.0
# 10       Girona  2015       12.18      254.9
# 11       Lleida  2017       11.81      254.9
# 12       Lleida  2016       12.83      254.6
# 13       Lleida  2015       12.49      254.8
# 14     Pirineus  2015         NaN        NaN
# 15    Tarragona  2017       12.96      254.9
# 16    Tarragona  2016       12.69      254.3
# 17    Tarragona  2015       12.84      254.9

# %% [markdown]
# Again, a **FULL JOIN** retrieves all the rows from both tables, joining the rows where the specified conditions are met and including rows that do not have corresponding matches in the other table. The None values and NaN in the output represent the instances where provinces and years exist in one table but not in the other.

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: Delete last added rows
query = f"""
    DELETE FROM `{pop_density}`
    WHERE 
        province IS NULL 
        OR province IN ('Costa Brava', 'Pirineus');
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %% [markdown]
# ### 4. Case Statements

# %% [markdown]
# **4.1. Within the '{mobile_2015_2017}' table, create a new column 'signal_eval' to categorize 'signal' values as follows:**
#
#     - 'Above avg' for values above 14
#     - 'On Avg' for values between 13 and 14
#     - 'Under Avg' for values below 13
#
# **Utilize SQL commands to examine 'signal' values and store corresponding evaluations in the 'signal_eval' column.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM
# - **Aggregated Functions**: MAX(), MIN(), AVG()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: max, min and average signal
query = f"""
    SELECT
      max(signal) max_signal,
      min(signal) min_signal,
      avg(signal) avg_signal
    FROM `{mobile_data_cleaned}`
    """

# Execute the query
query_df(query)
# Out:
#    max_signal  min_signal  avg_signal
# 0          99           0   13.215715

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: ALTER TABLE, ADD COLUMN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: create a new column to store the updated value
query = f"""
    ALTER TABLE `{mobile_data_cleaned}`
    ADD COLUMN signal_eval STRING;
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: UPDATE, SET, WHERE, AND, IS NULL
# - **Conditional Functions**: CASE, WHEN, THEN, ELSE, END
# - **Operators**: =, <, BETWEEN, >

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: update 'signal_eval' values according to 'signal' values
query = f"""
    UPDATE `{mobile_data_cleaned}`
    SET signal_eval =
        CASE
            WHEN signal < 13 THEN 'Under Avg'
            WHEN signal BETWEEN 13 AND 14 THEN 'On Avg'
            WHEN signal > 14 THEN 'Above Avg'
            END
        WHERE signal_eval IS NULL;
    """

# Execute the query and store the result in the DataFrame
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, LIMIT

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: check new values of 'signal_eval'
query = f"""
    SELECT
      signal,
      signal_eval
    FROM `{mobile_data_cleaned}`
    LIMIT 100
    """
# Execute the query
query_df(query)
# Out:
#     signal signal_eval
# 0       17   Above Avg
# 1        8   Under Avg
# 2        9   Under Avg
# 3        9   Under Avg
# 4       15   Above Avg
# ..     ...         ...
# 95      14      On Avg
# 96      14      On Avg
# 97      23   Above Avg
# 98      12   Under Avg
# 99      20   Above Avg
#
# [100 rows x 2 columns]

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: ALTER TABLE, DROP COLUMN

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: delete the 'signal_eval'
query = f"""
    ALTER TABLE `{mobile_data_cleaned}`
    DROP COLUMN signal_eval;
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %% [markdown]
# ### 5. Statistical Aggregate Functions

# %% [markdown]
# **5.1. Calculate the correlation coefficient between:**
#
# **- The average signal strength (signal) and population density for all provinces.**
#
# **- The average signal strength (signal) and per capita income for all provinces**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM
# - **Aggregate Functions**: AVG()
# - **Statistical Aggregate Functions**: CORR()
# - **Operators**: =
# - **Joins**: JOIN
# - **CTEs:** AvgSignalYearProvince

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
 -- CTE: Find the average signal strength by year and province
WITH AvgSignalYearProvince AS (
    SELECT
        m.year,
        m.province,
        AVG(m.signal) avg_signal
    FROM
        `{mobile_data_cleaned}` m
    GROUP BY m.year, m.province
)

SELECT 
     -- Calculate Pearson Correlation
    CORR(t.avg_signal, p.density_per_sq_km) corr_signal_density,
    CORR(t.avg_signal, c.per_capita_income) corr_signal_income
FROM AvgSignalYearProvince t
JOIN `{pop_density}` p 
  ON t.province = p.province AND t.year = p.year
JOIN `{percapita_income}` c 
  ON t.province = c.province AND t.year = c.year
"""

# Execute the query
query_df(query)
# Out:
#    corr_signal_density  corr_signal_income
# 0             0.707875            0.350269

# %% [markdown]
# The **corr_signal_density** coefficient of approximately 0.71 suggests a **moderately strong positive linear correlation** between the average signal strength (avg_signal) and population density (density_per_sq_km). This indicates that as population density increases, the average signal strength also tends to increase.
#
# On the other hand, the **corr_signal_income** value, indicating the correlation between average signal strength (avg_signal) and per capita income, also shows **a positive linear correlation but is notably weaker** than the correlation observed between average signal strength and population density in the previous analysis.

# %% [markdown]
# #### Analysis Insight: Correlation Coefficient Range
#
# _In the ongoing analysis of correlations, understanding the range of the correlation coefficient is pivotal in interpreting the relationships between variables._
#
# - *A correlation of 1* indicates a perfect positive linear relationship, signifying that as one variable increases, the other variable also increases proportionally.
# - *A correlation of -1* represents a perfect negative linear relationship, implying that as one variable increases, the other variable decreases proportionally.
# - *A correlation of 0* suggests no linear relationship between the variables.

# %% [markdown]
# **5.2. Calculate the covariance between 'signal' strength and 'speed' in the '{mobile_data_cleaned}' table.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM
# - **Statistical Aggregate Functions**: COVAR_POP(), CORR()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: 
query = f"""
    SELECT
      COVAR_POP(signal, speed) AS COVAR_signal_speed,
      CORR(signal, speed) AS CORR_signal_speed
    FROM `{mobile_data_cleaned}`
    """

# Execute the query
query_df(query)
# Out:
#    COVAR_signal_speed  CORR_signal_speed
# 0           -0.935596          -0.003577

# %% [markdown]
# The **covariance**, a measure indicating how two variables change together, displays a negative value of approximately -0.936, signifying a **negative linear relationship** between 'signal' and 'speed.' This implies that when one variable increases, the other tends to decrease, and vice versa. However, while covariance assesses the direction of the relationship, **it lacks interpretability and comparability**.
#
# Contrastingly, as previously discussed, the **correlation coefficient**, unlike covariance, serves as a standardized measure within the range of -1 to 1. The correlation value of approximately -0.004 suggests an **extremely weak linear relationship**, close to zero, indicating an absence of substantial linear correlation between 'signal' and 'speed' in the dataset. Therefore, while covariance indicates a negative relationship, the correlation coefficient underscores the lack of a strong linear connection between these variables.

# %% [markdown]
# **5.3. Calculate the standard deviation, minimum and maximum values, and average of 'signal' strength in the '{mobile_data_cleaned}' table for the year 2017.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE
# - **Aggregate Functions**: STDDEV_POP(), MIN(), MAX(), AVG()
# - **Mathematical Functions**: ROUND()
# - **Operators**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      ROUND(STDDEV_POP(signal),2) AS STD_signal,
      ROUND(MIN(signal),2) AS MIN_signal,
      ROUND(MAX(signal),2) AS MAX_signal,
      ROUND(AVG(signal),2) AS AVG_signal      
    FROM `{mobile_data_cleaned}`
    WHERE year = 2017
    """

# Execute the query
query_df(query)
# Out:
#    STD_signal  MIN_signal  MAX_signal  AVG_signal
# 0        7.18         0.0        65.0       12.66

# %% [markdown]
# These statistics provide insights into the variability and range of signal strengths in the dataset for the year 2017. The **standard deviation** of 7.18 indicates that signal strengths vary from the **average** (12.66) by an average of approximately 7.18 units, and the signal strength ranged from 0.0 to 65.0 during that year.

# %% [markdown]
# **5.4. Calculate the variance of 'speed' in the '{mobile_data_cleaned}' table for the year 2017.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE
# - **Statistical Functions**: VAR_POP(), STDDEV_POP()
# - **Mathematical Functions**: ROUND(), MAX(), MIN()
# - **Operators**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query:
query = f"""
    SELECT
      ROUND(VAR_POP(speed),2) VAR_speed,
      ROUND(STDDEV_POP(speed),2) AS STD_speed,
      MAX(speed) - MIN(speed) AS Range_speed
    FROM `{mobile_data_cleaned}`
    WHERE year=2017
    """

# Execute the query
query_df(query)
# Out:
#    VAR_speed  STD_speed  Range_speed
# 0    1186.43      34.44        254.9

# %% [markdown]
# The statistics for the 'speed' variable in the year 2017 reveal a **substantial degree of variability**, as evidenced by the high population **variance, standard deviation, and range**. This variation suggests that the data points for 'speed' exhibit a wide dispersion from the mean and cover a significant range, reflecting diverse speed measurements throughout the year 2017.

# %% [markdown]
# ### 6. Window Functions

# %% [markdown]
# Prior to delving into the application of RANK() and DENSE_RANK() window functions, we'll initiate the process by **inserting sample data into the {mobile_data_cleaned} table**. This dataset will be instrumental in our exploration of the nuances between both rank window functions, specifically when ranking operators possessing identical values across certain attributes.

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: INSERT INTO, VALUES

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: insert new rows into 'mobile_data_cleaned'
query = f"""
    INSERT INTO `{mobile_data_cleaned}` (net_provider, operator, net, signal, speed)
    VALUES
        ('invented_net_provider', 'invented_operator', '4G', 11, 13),
        ('invented_net_provider', 'invented_operator', '4G', 12, 14),
        ('invented_net_provider', 'invented_operator2', '4G', 12, 14)
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE
# - **String Functions**: REGEXP_CONTAINS()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}

# SQL Query: check added rows
query = f"""
    SELECT
        *
    FROM `{mobile_data_cleaned}`
    WHERE REGEXP_CONTAINS(operator,'invented')
    """

# Execute the query
query_df(query)
# Out:
#    date  hour   lat  long  signal           net_provider            operator  \
# 0  None  None  None  None      11  invented_net_provider   invented_operator
# 1  None  None  None  None      12  invented_net_provider   invented_operator
# 2  None  None  None  None      12  invented_net_provider  invented_operator2
#
#   description net  speed satellites precision position_provider activity  \
# 0        None  4G   13.0       None      None              None     None
# 1        None  4G   14.0       None      None              None     None
# 2        None  4G   14.0       None      None              None     None
#
#   postal_code town_name position_geom province  year
# 0        None      None          None     None  None
# 1        None      None          None     None  None
# 2        None      None          None     None  None

# %% [markdown]
# **Additionally, we will create a VIEW, {netwop_4G_view}, to filter and extract a specific subset of the data, focusing on '4G' net**.
#
# This view will serve as the basis for our exploration of window functions, allowing us to rank operators and gain insights into their network activity.

# %%
# View path 
netwop_4G_view = "bq-analyst-230590.project_cat_mobile_coverage_2015_2017.netw_op_4G_view"

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: CREATE OR REPLACE VIEW, SELECT, FROM, WHERE, GROUP BY, ORDER BY
# - **Aggregate Functions**: COUNT(), AVG()
# - **Mathematical Functions**: ROUND()
# - **Operators**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: create or replace view if exists
query = f"""
    CREATE OR REPLACE VIEW `{netwop_4G_view}` AS
    SELECT
      net_provider,
      operator,
      COUNT(*) AS activity_count,
      ROUND(AVG(signal), 2) AS avg_signal,
      ROUND(AVG(speed), 2) AS avg_speed
    FROM `{mobile_data_cleaned}`
    WHERE net = '4G'
    GROUP BY net_provider, operator
    ORDER BY net_provider
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: display View
query = f"""
    SELECT
      *
    FROM `{netwop_4G_view}`
    """

# Execute the query
query_df(query)
# Out:
#                   net_provider                    operator  activity_count  \
# 0             Bouygues Telecom            Bouygues Telecom              32
# 1                        Bytel                       Bytel            1228
# 2                           EE                          EE              73
# 3                        ESPRT                       ESPRT              20
# 4                    ETICOM SC                   ETICOM SC            1985
# 5                        F SFR                       F SFR             940
# 6      France Telcom Espana SA     France Telcom Espana SA           15656
# 7                      GurbTec                     GurbTec               2
# 8                        I TIM                       I TIM               1
# 9                      Jazztel                     Jazztel            7738
# 10                        Lowi                        Lowi               2
# ...

# %% [markdown]
# **6.1. How do net_providers within the '4G' net rank based on the number of operators, and which net_providers are at the top 10 in terms of operator count?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, GROUP BY, ORDER BY, LIMIT
# - **Aggregate Functions**: COUNT()
# - **Window Functions**: RANK(), DENSE_RANK(), OVER()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: Rank Vs Dense Rank
query = f"""
SELECT
  net_provider,
  COUNT(operator) operator_count,
  RANK() OVER(ORDER BY COUNT(operator) DESC) overall_rank_num_op,
  DENSE_RANK() OVER(ORDER BY COUNT(operator) DESC) overall_DENSE_rank_num_op
FROM `{netwop_4G_view}`
GROUP BY 1
ORDER BY 2 DESC, 1 ASC
LIMIT 10
    """

# Execute the query and store the result
ranks_df = query_df(query)  

# Print styled dataframe

# Call Function: styled_df_by_valyue(df, column, ['value1','value2',...], optional ['n-values']
styled_df_by_value(ranks_df, 'net_provider', ['Vodafone', 'invented_net_provider'], ['Bouygues Telecom'])
# Out:
# <style type="text/css">
# #T_d0916_row0_col0, #T_d0916_row0_col1, #T_d0916_row0_col2, #T_d0916_row0_col3, #T_d0916_row1_col0, #T_d0916_row1_col1, #T_d0916_row1_col2, #T_d0916_row1_col3, #T_d0916_row5_col0, #T_d0916_row5_col1, #T_d0916_row5_col2, #T_d0916_row5_col3, #T_d0916_row6_col0, #T_d0916_row6_col1, #T_d0916_row6_col2, #T_d0916_row6_col3, #T_d0916_row7_col0, #T_d0916_row7_col1, #T_d0916_row7_col2, #T_d0916_row7_col3, #T_d0916_row8_col0, #T_d0916_row8_col1, #T_d0916_row8_col2, #T_d0916_row8_col3, #T_d0916_row9_col0, #T_d0916_row9_col1, #T_d0916_row9_col2, #T_d0916_row9_col3 {
#   background-color: ;
# }
# #T_d0916_row2_col0, #T_d0916_row2_col1, #T_d0916_row2_col2, #T_d0916_row2_col3, #T_d0916_row3_col0, #T_d0916_row3_col1, #T_d0916_row3_col2, #T_d0916_row3_col3 {
#   background-color: #9370DB;
# }
# #T_d0916_row4_col0, #T_d0916_row4_col1, #T_d0916_row4_col2, #T_d0916_row4_col3 {
#   background-color: #8A2BE2;
# }
# </style>
# <table id="T_d0916">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# **Both RANK() and DENSE_RANK() assign a rank to rows based on the descending count of operators**. However, **RANK()** provides a ranking where identical values receive the same rank, potentially resulting in **skipped ranks** if there are ties among values. Conversely, **DENSE_RANK()** assigns a **rank without gaps**, ensuring a continuous sequence of ranks even if there are ties among values, guaranteeing no gaps in the ranking sequence.
#
# For instance, **'Vodafone'** and **'invented_net_provider'** both share the **same count (2)** and have an **overall rank of 3**. However, following this, in 'overall_rank_num_op', **'Bouygues Telecom'** receives the **rank 5, skipping the rank 4** due to the tied counts in the 'operator_count' column.
#
# **'Vodafone'** and **'invented_net_provider'** do also share an overall dense rank of 3. However, as DENSE_RANK() provides continuous ranks without gaps, 'Bouygues Telecom' receives the **rank 4**, without any skipped values in the sequence.

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: DELETE FROM, WHERE
# - **Operators**: REGEXP_CONTAINS()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: delete last added rows
query = f"""
    DELETE FROM `{mobile_data_cleaned}`
    WHERE REGEXP_CONTAINS(operator,'invented')
    """

# Execute the query
run_query(query)
# Out:
# Query successfully executed, and the table has been updated.

# %% [markdown]
# **6.2. Within '4G' net_providers with multiple operators, how are operators ranked based on their activity count, and what is the comparative distribution of their rankings within their respective net_providers?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, WHERE, IN, GROUP BY, HAVING, ORDER BY, DESC
# - **Aggregate Functions**: COUNT(), DISTINCT()
# - **Window Functions**: RANK(), PERCENT_RANK(), OVER()
# - **Partitioning**: PARTITION BY
# - **Operators**: = >
# - **Subqueries**
# - **CTEs**: FilteredNetProvider

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: PERCENT_RANK()
query = f"""
 -- CTE: select only data from net_providers with multiple operators
WITH FilteredNetProvider AS (
  SELECT
    net_provider
  FROM `{netwop_4G_view}`
  GROUP BY net_provider
  HAVING COUNT(DISTINCT operator) > 1
)

SELECT
  net_provider,
  operator,
  activity_count,
   -- DESC ensures that the rank assignation starts from the highest activity_count value
  RANK() OVER (PARTITION BY net_provider ORDER BY activity_count ASC) AS rank_within_netprovider,
  PERCENT_RANK() OVER (PARTITION BY net_provider ORDER BY activity_count DESC) AS percent_rank_within_netprovider,
  RANK() OVER (ORDER BY activity_count DESC) AS overall_rank
FROM `{netwop_4G_view}`
WHERE net_provider IN (
     -- Subquery to select only filtered net_providers from the CTE
    SELECT net_provider 
    FROM FilteredNetProvider
    )
ORDER BY 1, 4 ASC
    """

# Execute the query and store the result
multiple_op_df = query_df(query)

# Display as styled df
styled_df_by_value(multiple_op_df, 'net_provider', ['Movistar'], ['Orange'],['Vodafone'])
# Out:
# <style type="text/css">
# #T_26d28_row0_col0, #T_26d28_row0_col1, #T_26d28_row0_col2, #T_26d28_row0_col3, #T_26d28_row0_col4, #T_26d28_row0_col5, #T_26d28_row1_col0, #T_26d28_row1_col1, #T_26d28_row1_col2, #T_26d28_row1_col3, #T_26d28_row1_col4, #T_26d28_row1_col5, #T_26d28_row2_col0, #T_26d28_row2_col1, #T_26d28_row2_col2, #T_26d28_row2_col3, #T_26d28_row2_col4, #T_26d28_row2_col5 {
#   background-color: #9370DB;
# }
# ...

# %% [markdown]
# The **PERCENT_RANK()** function calculates the **relative rank of a row within a partition as a percentage, from 0 to 1**. It represents the position of a row concerning the total number of rows in the partition.
#
# In our case, we use PERCENT_RANK() to determine the percentile rank of each row **based on the activity_count within each net_provider group**. The PARTITION BY net_provider clause divides the data into partitions per net_provider, and the ORDER BY activity_count DESC sorts the rows within each partition by activity_count in descending order.

# %% [markdown]
# **6.3. How does the moving average signal strength within the 'Orange' network for each operator compare to their respective average signal strength?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, GROUP BY, ORDER BY, ASC
# - **Window Functions**: AVG(), OVER(), PARTITION BY, {ROWS BETWEEN, PRECEDING, FOLLOWING}
# - **Ooperators**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: moving average AVG()
query = f"""
SELECT
  net_provider,
  operator,
  avg_signal,
  AVG(avg_signal) OVER (PARTITION BY net_provider ORDER BY avg_signal ROWS BETWEEN 2 PRECEDING AND 2 FOLLOWING) AS moving_avg_signal
FROM `{netwop_4G_view}`
WHERE net_provider = 'Orange'
GROUP BY 1,2,3
ORDER BY 1, 2 ASC
    """

# Execute the query
query_df(query)
# Out:
#   net_provider   operator  avg_signal  moving_avg_signal
# 0       Orange  EUSKALTEL       10.00          11.436667
# 1       Orange   FIBRACAT       12.32          12.312000
# 2       Orange    Jazztel       12.32          12.448000
# 3       Orange   Masmovil       13.62          13.216667
# 4       Orange     Orange       13.32          13.065000
# 5       Orange     PARLEM       12.28          11.790000
# 6       Orange       RACC       12.71          12.916000
# 7       Orange      Simyo       12.61          12.656000
# 8       Orange      adamo       12.03          11.657500

# %% [markdown]
# To calculate the **moving average**, it considers the signal strength values of each operator and **computes the average of the surrounding values** within a window of - in our case- two preceding and two following rows (including the operator's value). This provides an estimate of signal strength variations for each operator within the network, which can be useful for identifying trends and deviations in signal strength over time.

# %% [markdown]
# **6.4. Can we divide operators in the '4G' net into quartiles based on their average signal strength, and what insights can we gain into the performance variation within each quartile?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, GROUP BY, ORDER BY
# - **Aggregate Functions**: COUNT(), MIN(), MAX(), AVG()
# - **Window Functions**: NTILE() OVER(), PARTITION BY
# - **CTEs**: Quartiles

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: NTILE()
query = f"""
 -- CTE: Assign quartiles within each net_provider
WITH Quartiles AS (
    SELECT
        operator,
        avg_signal,
         -- Divide operators into quartiles (1-4), with 1 being the lowest and 4 being the highest signal strength quartile.
        NTILE(4) OVER (PARTITION BY net_provider ORDER BY avg_signal) AS signal_quartile 
    FROM `{netwop_4G_view}`
    )

SELECT
  signal_quartile,
  COUNT(operator) AS operator_count,
  MIN(avg_signal) AS min_avg_signal,
  MAX(avg_signal) AS max_avg_signal,
  AVG(avg_signal) AS avg_signal
FROM Quartiles
GROUP BY signal_quartile
ORDER BY signal_quartile
    """

# Execute the query
query_df(query)
# Out:
#    signal_quartile  operator_count  min_avg_signal  max_avg_signal  avg_signal
# 0                1              29            7.00           27.00   12.758276
# 1                2               4           12.32           14.05   12.885000
# 2                3               3           12.61           13.36   12.893333
# 3                4               2           13.32           13.62   13.470000

# %% [markdown]
# This analysis examines the '4G' net operators grouped into quartiles based on their average signal strengths, providing valuable insights into the performance variations among different telecommunication providers.
#
# Quartile 1 - Lowest Signal Strength:
#
# - This quartile contains the highest count of operators, totaling 29. It represents a substantial portion of operators exhibiting relatively lower average signal strengths, ranging from 7.00 to 27.00.
#
# Quartile 2:
#
# - With a comparatively smaller count of operators (4), Quartile 2 displays a slightly improved signal strength compared to Quartile 1, averaging around 12.89.
#
# Quartile 3:
#
# - Quartile 3 comprises an even smaller number of operators (3), exhibiting signal strengths similar to those in Quartile 2, hovering around an average of 12.89.
#
# Quartile 4 - Highest Signal Strength:
#
# - Representing the smallest group of operators (2), Quartile 4 comprises operators with the highest average signal strengths, ranging from 13.32 to 13.62.
#
# The comparative analysis between these quartiles unveils a noticeable separation in signal strength. Quartile 1 includes a larger set of operators with relatively lower signal strengths, while Quartile 4 encompasses a select few with notably higher signal strengths. Quartiles 2 and 3 reveal relatively similar signal strength patterns, falling between the lowest and highest signal strength quartiles.

# %% [markdown]
# **6.5. What insights can we gain about average signal strength changes and average speed variations among operators in the '4G' net, especially within the 'Orange' net_provider category, using LEAD and LAG window functions without considering time-based changes?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, GROUP BY, ORDER BY, ASC
# - **Window Function**: LEAD() OVER(), PARTITION BY
# - **Operator**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: LEAD(), signal
query = f"""
SELECT
    net_provider,
    operator,
    avg_signal,
     -- LEAD() takes the avg_speed of (current row_num + 1)
    LEAD(avg_signal) OVER (PARTITION BY net_provider ORDER BY avg_signal) lead_avg_signal
    FROM `{netwop_4G_view}`
WHERE net_provider = 'Orange'
GROUP BY 1,2,3
ORDER BY 3 ASC
    """

# Execute the query
query_df(query)
# Out:
#   net_provider   operator  avg_signal  lead_avg_signal
# 0       Orange  EUSKALTEL       10.00            12.03
# 1       Orange      adamo       12.03            12.28
# 2       Orange     PARLEM       12.28            12.32
# 3       Orange   FIBRACAT       12.32            12.32
# 4       Orange    Jazztel       12.32            12.61
# 5       Orange      Simyo       12.61            12.71
# 6       Orange       RACC       12.71            13.32
# 7       Orange     Orange       13.32            13.62
# 8       Orange   Masmovil       13.62              NaN

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, GROUP BY, ORDER BY, ASC
# - **Window Function**: LAG() OVER(), PARTITION BY
# - **Operator**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: LAG(), speed
query = f"""
SELECT
    net_provider,
    operator,
    avg_speed,
     -- LAG( ,3) takes the avg_speed of (current row_num - 3)
    LAG(avg_speed,3) OVER(PARTITION BY net_provider ORDER BY avg_speed) lag_avg_speed
FROM `{netwop_4G_view}`
WHERE net_provider = 'Orange'
GROUP BY 1,2,3
ORDER BY 3 ASC
    """

# Execute the query
query_df(query)
# Out:
#   net_provider   operator  avg_speed  lag_avg_speed
# 0       Orange   FIBRACAT       3.96            NaN
# 1       Orange     PARLEM      12.10            NaN
# 2       Orange   Masmovil      13.43            NaN
# 3       Orange      Simyo      15.96           3.96
# 4       Orange       RACC      18.70          12.10
# 5       Orange    Jazztel      21.87          13.43
# 6       Orange     Orange      23.66          15.96
# 7       Orange      adamo      29.27          18.70
# 8       Orange  EUSKALTEL      84.10          21.87

# %% [markdown]
# **6.6. Among 'Orange' operators in the '4G' net, how does their ranking based on average signal strength compare to their ranking based on the number of records? Do 'Orange' operators with strong average signal strength also have a larger volume of records, and does this impact their overall ranking?**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, ORDER BY, DESC
# - **Window Function**: ROW_NUMBER() OVER(), PARTITION BY
# - **Operators**: =

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL Query: ROW_NUMBER()
query = f"""
SELECT
    operator,
    avg_signal AS signal_strength,
     -- ROW_NUMBER: assigns a unique sequential number to each row within a partition or the result set
    ROW_NUMBER() OVER (PARTITION BY net_provider ORDER BY avg_signal DESC) AS signal_rank,
    activity_count AS record_count,
    ROW_NUMBER() OVER (PARTITION BY net_provider ORDER BY activity_count DESC) AS record_rank
FROM `{netwop_4G_view}`
WHERE net_provider = 'Orange'
ORDER BY signal_rank;
    """

# Execute the query and store result
signalrank_df = query_df(query)

# Display as styled df
styled_df_by_value(signalrank_df, 'operator', ['Masmovil','RACC'], ['Jazztel'])
# Out:
# <style type="text/css">
# #T_ff27e_row0_col0, #T_ff27e_row0_col1, #T_ff27e_row0_col2, #T_ff27e_row0_col3, #T_ff27e_row0_col4, #T_ff27e_row2_col0, #T_ff27e_row2_col1, #T_ff27e_row2_col2, #T_ff27e_row2_col3, #T_ff27e_row2_col4 {
#   background-color: #9370DB;
# }
# #T_ff27e_row1_col0, #T_ff27e_row1_col1, #T_ff27e_row1_col2, #T_ff27e_row1_col3, #T_ff27e_row1_col4, #T_ff27e_row3_col0, #T_ff27e_row3_col1, #T_ff27e_row3_col2, #T_ff27e_row3_col3, #T_ff27e_row3_col4, #T_ff27e_row4_col0, #T_ff27e_row4_col1, #T_ff27e_row4_col2, #T_ff27e_row4_col3, #T_ff27e_row4_col4, #T_ff27e_row6_col0, #T_ff27e_row6_col1, #T_ff27e_row6_col2, #T_ff27e_row6_col3, #T_ff27e_row6_col4, #T_ff27e_row7_col0, #T_ff27e_row7_col1, #T_ff27e_row7_col2, #T_ff27e_row7_col3, #T_ff27e_row7_col4, #T_ff27e_row8_col0, #T_ff27e_row8_col1, #T_ff27e_row8_col2, #T_ff27e_row8_col3, #T_ff27e_row8_col4 {
#   background-color: ;
# }
# #T_ff27e_row5_col0, #T_ff27e_row5_col1, #T_ff27e_row5_col2, #T_ff27e_row5_col3, #T_ff27e_row5_col4 {
# ...

# %% [markdown]
# We can observe that the ranking based on signal strength doesn't necessarily correlate with the ranking based on the number of records.
#
# For instance, operators such as Masmovil or RACC, having the first and third-highest signal strengths, are respectively ranked sixth and seventh out of nine in terms of record count, indicating a lower presence in the network. In contrast, Jazztel, ranked sixth in signal strength, secures the second position in record rank.

# %% [markdown]
# ### 7. Datetime Functions & Visualization

# %% [markdown]
# In this section, we will continue our exploration of querying techniques as we have been doing, but to augment the analysis, we will harness too the power of Matplotlib and Seaborn libraries, leveraging various visualization techniques such as bar plots, pie charts, and scatter plots. These visual aids will provide an additional layer of understanding to our data exploration and interpretation.

# %% [markdown]
# #### Import libraries

# %%
# Matplotlib enables the reation of various visualizations such as plots, charts, and figures.
import matplotlib.pyplot as plt

# Seaborn enhances matplotlib for statistical graphics, offering more informative and visually appealing visualizations.
import seaborn as sns

# The calendar module provides functionalities for working with dates and calendars in Python.
import calendar

# %% [markdown]
# **7.1. Calculate the duration in days, months and years between the first and last records in the table**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM
# - **Aggregate Functions**: MIN(), MAX()
# - **Date Function**: DATE_DIFF(), DAY, MONTH, YEAR
# - **Operators**: -

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query
query = f"""
    SELECT
        MIN(date) AS first_date_recorded,
        MAX(date) AS last_date_recorded,
        DATE_DIFF(MAX(date), MIN(date), DAY) AS total_days,
        DATE_DIFF(MAX(date), MIN(date), MONTH) AS total_months,
        DATE_DIFF(MAX(date), MIN(date), YEAR) AS total_years
    FROM `{mobile_data_cleaned}`
    """

# Execute the query
query_df(query)
# Out:
#   first_date_recorded last_date_recorded  total_days  total_months  \
# 0          2015-01-05         2017-12-31        1091            35
#
#    total_years
# 0            2

# %% [markdown]
# **7.2. What is the quarterly and overall monthly ranking of records based on count for the dataset "{mobile_data_cleaned}"? Display the quarter, month, abbreviated month name, total record count, and the rank within the quarter and across the entire year.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, GROUP BY, ORDER BY, DESC
# - **Aggregate Functions**: COUNT()
# - **Conditional Logic**: CASE, WHEN, END
# - **Date Function**: EXTRACT(), QUARTER, MONTH
# - **Window Functions**: RANK() OVER(), PARTITION BY
# - **Joins**: JOIN
# - **CTEs**: MonthlyCounts, MonthNamesAbbr

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query
query = f"""
     -- CTE: Extracts quarters and months from date, and counts records.
    WITH MonthlyCounts AS (
        SELECT
            EXTRACT(QUARTER FROM date) AS quarter,
            EXTRACT(MONTH FROM date) AS month,
            COUNT(*) AS record_count
        FROM `{mobile_data_cleaned}`
        GROUP BY quarter, month
        ),
    
    -- CTE: transforms the numerical representation of months into their respective abbreviated names
   MonthNamesAbbr AS (
        SELECT
            month,
            CASE
                WHEN month = 1 THEN 'JAN'
                WHEN month = 2 THEN 'FEB'
                WHEN month = 3 THEN 'MAR'
                WHEN month = 4 THEN 'APR'
                WHEN month = 5 THEN 'MAY'
                WHEN month = 6 THEN 'JUN'
                WHEN month = 7 THEN 'JUL'
                WHEN month = 8 THEN 'AUG'
                WHEN month = 9 THEN 'SEP'
                WHEN month = 10 THEN 'OCT'
                WHEN month = 11 THEN 'NOV'
                WHEN month = 12 THEN 'DEC'
            END AS month_abbr
        FROM `MonthlyCounts`
        GROUP BY month
        )

    SELECT
      c.quarter,
      c.month,
      n.month_abbr,
      c.record_count,
       -- Month rank within the quarter
      RANK() OVER(PARTITION BY c.quarter ORDER BY c.record_count DESC) AS month_rank_within_quarter,
       -- Month rank within the whole year
      RANK() OVER (ORDER BY c.record_count DESC) AS overall_month_rank
    FROM MonthlyCounts c
    JOIN MonthNamesAbbr n
      ON c.month = n.month
    ORDER BY c.quarter, c.month, c.record_count DESC;
    """

# Execute the query and store the result
month_rank_df = query_df(query) 

# Display as styled df
styled_df_by_value(month_rank_df, 'quarter', [1,3],[2,4])
# Out:
# <style type="text/css">
# #T_4e807_row0_col0, #T_4e807_row0_col1, #T_4e807_row0_col2, #T_4e807_row0_col3, #T_4e807_row0_col4, #T_4e807_row0_col5, #T_4e807_row1_col0, #T_4e807_row1_col1, #T_4e807_row1_col2, #T_4e807_row1_col3, #T_4e807_row1_col4, #T_4e807_row1_col5, #T_4e807_row2_col0, #T_4e807_row2_col1, #T_4e807_row2_col2, #T_4e807_row2_col3, #T_4e807_row2_col4, #T_4e807_row2_col5, #T_4e807_row6_col0, #T_4e807_row6_col1, #T_4e807_row6_col2, #T_4e807_row6_col3, #T_4e807_row6_col4, #T_4e807_row6_col5, #T_4e807_row7_col0, #T_4e807_row7_col1, #T_4e807_row7_col2, #T_4e807_row7_col3, #T_4e807_row7_col4, #T_4e807_row7_col5, #T_4e807_row8_col0, #T_4e807_row8_col1, #T_4e807_row8_col2, #T_4e807_row8_col3, #T_4e807_row8_col4, #T_4e807_row8_col5 {
#   background-color: #9370DB;
# }
# ...

# %% [markdown]
# **7.2.1. Create a bar plot representing the quarterly record counts per individual month based on the prior query output. Also, identify the overall average count present in the plotted data.**

# %%
# Define custom color palettes for each quarter
colors_first_quarter = sns.color_palette("Blues", n_colors=3)
colors_second_quarter = sns.color_palette("Greens", n_colors=3)
colors_third_quarter = sns.color_palette("Oranges", n_colors=3)
colors_fourth_quarter = sns.color_palette("Purples", n_colors=3)

# Prepare data for a bar plot
bar_df = month_rank_df.pivot(index='quarter', columns='month', values='record_count')

# Dictionary to map month numbers to abbreviated month names
month_abbr = [calendar.month_abbr[i] for i in range(1, 13)]
month_abbr_dict = {i: month_abbr[i - 1] for i in range(1, 13)}

# Rename columns to abbreviated month names
bar_df.columns = [month_abbr_dict[col] for col in bar_df.columns]

# Create a bar plot
plt.figure(figsize=(12, 6))

# Loop through quarters and plot bars with their custom color palette
quarters = bar_df.index
for quarter, color_palette in zip(quarters, [colors_first_quarter, colors_second_quarter, colors_third_quarter, colors_fourth_quarter]):
    quarter_data = bar_df.loc[quarter]
    quarter_data.plot(kind='bar', stacked=True, color=color_palette, label=f'Quarter {quarter}')

# Calculate the overall average for all values
overall_average = bar_df.stack().mean()

# Plot a red horizontal line for the overall average
plt.axhline(y=overall_average, color='red', linestyle='--', label=f'Avg. Overall')

plt.title('Bar Plot of Quarter-wise Record Counts with Distinct Colors for Months')
plt.xlabel('Month')  # X-axis label showing abbreviated month names
plt.ylabel('Record Count')
plt.legend(title='Legend', loc='upper right', bbox_to_anchor=(1.15, 1))
plt.ticklabel_format(style='plain', axis='y')  # Disable scientific notation on y-axis
plt.show()

# %% [markdown]
# **7.3. Query to determine the count of records grouped by time periods categorized as Dawn, Morning, Afternoon, and Night based on hour ranges.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, AND, GROUP BY, ORDER BY, DESC,
# - **Aggregate Functions**: COUNT()
# - **Conditional Logic**: CASE, THEN, ELSE, END
# - **Operator**: BETWEEN
# - **Date Function**: EXTRACT(), HOUR

# %%
# SQL query
query = f"""
    SELECT
      CASE
        WHEN EXTRACT(HOUR FROM hour) BETWEEN 0 AND 6 THEN 'Dawn (00-07h)'
        WHEN EXTRACT(HOUR FROM hour) BETWEEN 7 AND 12 THEN 'Morning (07-12h)'
        WHEN EXTRACT(HOUR FROM hour) BETWEEN 13 AND 18 THEN 'Afternoon (12-18h)'
        ELSE 'Night (18-00h)'
      END AS period,
      COUNT(*) AS record_count
    FROM `{mobile_data_cleaned}`
    GROUP BY 1
    ORDER BY 2 DESC
    """

# Execute the query and store the result
hourly_period_counts = query_df(query)

hourly_period_counts
# Out:
#                period  record_count
# 0  Afternoon (12-18h)       4085296
# 1    Morning (07-12h)       3921515
# 2      Night (18-00h)       2173939
# 3       Dawn (00-07h)        474663

# %% [markdown]
# **7.3.1. Code to visualize the distribution of records among time periods, showcasing the proportion of records in each categorized period.**

# %%
# Extracting data to plot
labels = hourly_period_counts['period'] 
sizes = hourly_period_counts['record_count'] 

# Create a figure for the pie chart
plt.figure(figsize=(4, 4))

# Plot a pie chart based on the record counts for each time period
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# Title of the pie chart
plt.title('Distribution of Records by Time Period')

plt.show()

# %% [markdown]
# ### 8. Extra Queries

# %% [markdown]
# **8.1. Query the top 10 towns excluding the provincial capitals (Barcelona, Tarragona, Girona, Lleida) with the highest mobile activity recorded. Retrieve the count of activities in each town, identified by postal code, town name, and province.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: SELECT, FROM, WHERE, NOT IN, GROUP BY, ORDER BY, DESC, LIMIT
# - **Aggregate Functions**: COUNT()

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query
query = f"""
    SELECT
      province,
      postal_code,
      town_name,
      COUNT(*) AS activity_record_count
    FROM `{mobile_data_cleaned}`
    WHERE town_name NOT IN ('Barcelona', 'Tarragona', 'Girona', 'Lleida')
    GROUP BY postal_code, town_name, province
    ORDER BY 4 DESC
    LIMIT 10
    """

# Execute the query
query_df(query)
# Out:
#     province postal_code                  town_name  activity_record_count
# 0  Tarragona      431233                       Reus                 230062
# 1  Barcelona      081017  l'Hospitalet de Llobregat                 223363
# 2  Barcelona      082055      Sant Cugat del Vallès                 218475
# 3  Barcelona      080155                   Badalona                 169788
# 4  Barcelona      081878                   Sabadell                 139514
# 5  Barcelona      082798                   Terrassa                 125573
# 6  Barcelona      083054     Vilafranca del Penedès                 125157
# 7  Barcelona      081136                    Manresa                 122619
# 8  Barcelona      080961                 Granollers                 101377
# 9  Barcelona      081213                     Mataró                  96075

# %% [markdown]
# **8.2. Retrieve unique pairs of net providers and operators alongside their average signal, average speed, activity records, and market share.**
#
# The market share is calculated as a percentage of the total activity records among all pairs of net providers and operators, excluding those with the lowest market shares.

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, WHERE, GROUP BY, ORDER BY, DESC
# - **Aggregate Functions**: AVG(), COUNT()
# - **String Functions**: CONCAT()
# - **Window Function**: SUM() OVER()
# - **Operators**: *, /
# - **Subquery**
# - **CTEs**: UniquePairs

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query: CTE, Subquery, Window Function (SUM() OVER())
query = f"""
 -- CTE: Uique pairs net_provider+operator, and get avg signal and speed, and activity_record
WITH UniquePairs AS (
    SELECT
        CONCAT(net_provider, ' - ', operator) AS netprovider_operator,
        ROUND(AVG(signal), 2) AS avg_signal,
        ROUND(AVG(speed), 2) AS avg_speed,
        COUNT(*) AS activity_record
    FROM `{mobile_data_cleaned}`
    GROUP BY 1
)

SELECT
    netprovider_operator,
    avg_signal,
    avg_speed,
    activity_record,
    ROUND((activity_record * 100.0) / total_activity_records,2) AS market_share
FROM (
     -- Subquery to calculate total_activity_records (SUM of all activity_records in the CTE)
    SELECT
        *,
        SUM(activity_record) OVER () AS total_activity_records
    FROM UniquePairs
) AS DataWithMarketShare
 -- Filters out the lowest values of market share
WHERE ROUND((activity_record * 100.0) / total_activity_records,2) > 0.00
ORDER BY activity_record DESC;
    """

# Execute the query and store the result in the DataFrame
unique_pairs_df = query_df(query)

unique_pairs_df.head(20)
# Out:
#                                  netprovider_operator  avg_signal  avg_speed  \
# 0                                 Movistar - Movistar       12.91      26.76
# 1                                 Vodafone - Vodafone       13.88      25.78
# 2                                     Orange - Orange       13.27      25.34
# 3                                    Orange - Jazztel       12.59      25.51
# 4                                Movistar - Pepephone       12.88      26.68
# 5                                       Yoigo - Yoigo       12.95      26.42
# 6                                       Orange - RACC       13.63      20.05
# 7                                      Orange - Simyo       13.82      20.87
# 8                                     Orange - PARLEM       12.89      14.36
# 9                                      Movistar - ONO       14.58      22.09
# 10                                  Movistar - Tuenti       13.08      27.97
# ...

# %% [markdown]
# **8.2.1. Visualize the relationship between Market Share and Average Signal, as well as Market Share and Average Speed, by plotting scatter plots and overlaying a trend line to display the trend between these variables.**

# %%
# Plot settings
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Scatter plot against avg_signal
sns.scatterplot(data=unique_pairs_df, x='market_share', y='avg_signal', ax=axs[0])
# Adding a trend line to display the relationship between Market Share and Avg. Signal
sns.regplot(data=unique_pairs_df, x='market_share', y='avg_signal', scatter=False, color='red', ax=axs[0])
axs[0].set_title('Market Share vs Avg. Signal')
axs[0].set_xlabel('Market Share %')
axs[0].set_ylabel('Avg. Signal')

# Scatter plot against avg_speed
sns.scatterplot(data=unique_pairs_df, x='market_share', y='avg_speed', ax=axs[1])
# Adding a trend line to display the relationship between Market Share and Avg. Speed
sns.regplot(data=unique_pairs_df, x='market_share', y='avg_speed', scatter=False, color='red', ax=axs[1])
axs[1].set_title('Market Share vs Avg. Speed')
axs[1].set_xlabel('Market Share %')
axs[1].set_ylabel('Avg. Speed')

plt.tight_layout()
plt.show()

# %% [markdown]
# _Red line is the trend, shaded area represents the confidence interval_

# %% [markdown]
# **8.3. Fetching the net providers that fall within the top 10% based on the volume of recorded activities, in addition to the count of operators associated and the average signal strength for each net provider.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, DISTINCT, FROM, WHERE, GROUP BY, ORDER BY, ASC, DESC
# - **Aggregate Functions**: ROUND(), COUNT(), AVG()
# - **Window Functions**: RANK(), PERCENT_RANK(), NTILE(), OVER()
# - **String Functions**: LOWER()
# - **Operators**: =
# - **Subquery**
# - **CTE**: Top10Percent

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query:
query = f"""
 -- CTE: Calculates and assignes percentiles
WITH Top10Percent AS (
  SELECT
    net_provider,
    num_operator,
    record_count,
    RANK() OVER (ORDER BY record_count DESC) AS record_count_rank,
    PERCENT_RANK() OVER (ORDER BY record_count ASC) AS record_count_percent_rank,
    avg_signal,
    percentile
  FROM (
    -- Subquery to generate the percentiles
    SELECT
      LOWER(net_provider) AS net_provider,  
       -- Calculate the number of distinct operators for each net_provider
      COUNT(DISTINCT LOWER(operator)) AS num_operator,
       -- Calculate the number of recorded activities for each net_provider
      COUNT(*) AS record_count,
      ROUND(AVG(signal), 1) AS avg_signal,
       -- Segment the data into 10 distinct percentiles based on the record counts 
      NTILE(10) OVER (ORDER BY COUNT(*) DESC) AS percentile
    FROM`{mobile_data_cleaned}`
    GROUP BY 1
  ) -- Closing subquery
) -- Closing CTE

SELECT
  net_provider,
  num_operator,
  record_count,
  record_count_rank,
  record_count_percent_rank,
  avg_signal
FROM Top10Percent
 -- Select the percentile representing the top 10% with the highest count of recorded activities
WHERE percentile = 1
ORDER BY record_count_rank ASC;
    """
# Execute the query
query_df(query)
# Out:
#    net_provider  num_operator  record_count  record_count_rank  \
# 0      movistar             5       4663488                  1
# 1        orange            12       2774427                  2
# 2      vodafone             4       2648741                  3
# 3         yoigo             1        357876                  4
# 4  eroski movil             1         39869                  5
# 5       jazztel             1         28351                  6
#
#    record_count_percent_rank  avg_signal
# 0                   1.000000        12.9
# 1                   0.980769        13.2
# 2                   0.961538        13.9
# 3                   0.942308        13.0
# 4                   0.923077        11.0
# 5                   0.903846        11.9

# %% [markdown]
# **8.4. Discover the top network providers and operators, excluding operators 'Movistar,' 'Vodafone,' and 'Orange,' for each province based on their record count, displaying the leading network provider and operator within each province.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, WHERE, GROUP BY, ORDER BY, DESC
# - **Aggregate Functions**: COUNT()
# - **String Functions**: LOWER()
# - **Window Functions**: RANK(), OVER(), PARTITION BY
# - **Joins**: JOIN
# - **Operators**: =
# - **Subqueries**
# - **CTEs**: ProvinceActivity, RankedNetwork, RankedOperator

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query
query = f"""
 -- CTE: Counts the records based on net_provider, operator, and province (except when operator is 'Movistar', 'Vodafone', or 'Orange').
WITH ProvinceActivity AS (
  SELECT
    province,
    LOWER(net_provider) AS net_provider,
    LOWER(operator) AS operator,
    COUNT(*) AS record_count
  FROM `{mobile_data_cleaned}`
  WHERE operator NOT IN ('Movistar', 'Vodafone', 'Orange')
  GROUP BY province, net_provider, operator
)

  -- CTE: Find the Rank of Network and Operator by Record Count for Each Province
, RankedNetwork AS (
  SELECT
    province,
    net_provider,
    operator,
    record_count,
    RANK() OVER (PARTITION BY province ORDER BY record_count DESC) AS net_provider_rank
  FROM ProvinceActivity
)
  -- CTE: Determines the rank of operators based on the count of records for each province. 
, RankedOperator AS (
  SELECT
    province,
    net_provider,
    operator,
    record_count,
    RANK() OVER (PARTITION BY province ORDER BY record_count DESC) AS operator_rank
  FROM ProvinceActivity
)

 -- Select the Top Net_Provider and Top Operator for Each Province
SELECT
  p.province,
  n.net_provider AS top_net_provider,
  o.operator AS top_operator
FROM RankedNetwork n
JOIN RankedOperator o 
  ON n.province = o.province AND n.net_provider_rank = 1 AND o.operator_rank = 1
JOIN (
     -- Subquery to provide a set of unique provinces
    SELECT DISTINCT province 
    FROM ProvinceActivity
    ) p 
  ON n.province = p.province
ORDER BY p.province;
    """
# Execute the query
query_df(query)
# Out:
#     province top_net_provider top_operator
# 0  Barcelona           orange      jazztel
# 1     Girona           orange      jazztel
# 2     Lleida         movistar    pepephone
# 3  Tarragona           orange         racc

# %% [markdown]
# **8.5. List the descriptions and activities along with their rankings based on the count of records. Additionally, display the most frequent town and its respective province for each unique pair of description and activity. The query filters out 'STATE_EMERGENCY_ONLY' and 'STATE_POWER_OFF' descriptions and 'UNKNOWN' activities. It then combines the results to show the overall ranking and the most frequent town within each description and activity pair.**

# %% [markdown]
# **SQL Query Structure and Functions Utilized:**
#
# - **Clauses**: WITH, SELECT, FROM, JOIN, GROUP BY, ORDER BY
# - **Aggregate Functions**: COUNT()
# - **Window Functions**: RANK() OVER(), PARTITION B
# - **Operators**: =, !=
# - **CTEs**: ActivityRank, MostFrequentTown

# %%
# Datasets: {mobile_data_cleaned}, {pop_density}, {percapita_income}, 
# Views: {netwop_4G_view}

# SQL query
query = f"""
 -- CTE: Calculate the rank of activities by description
WITH ActivityRank AS (
  SELECT
    description,
    activity,
    RANK() OVER (PARTITION BY description ORDER BY COUNT(*) DESC) AS rank_by_description,
    COUNT(*) AS record_count
  FROM `{mobile_data_cleaned}`
  WHERE 
    description NOT IN ('STATE_EMERGENCY_ONLY', 'STATE_POWER_OFF')
    AND activity != 'UNKNOWN'
  GROUP BY description, activity
),

 --CTE: Find the most frequent town for each unique pair of description and activity
MostFrequentTown AS (
  SELECT
    description,
    activity,
    town_name,
    province,
    RANK() OVER (PARTITION BY description, activity ORDER BY COUNT(*) DESC) AS town_rank
  FROM `{mobile_data_cleaned}`
  GROUP BY description, activity, town_name, province
)

SELECT
  ar.description,
  ar.activity,
  ar.rank_by_description,
  RANK() OVER (ORDER BY ar.rank_by_description, ar.record_count DESC) AS overall_rank,
  mft.town_name AS most_frequent_town,
  mft.province
FROM ActivityRank ar
JOIN MostFrequentTown mft 
  ON ar.description = mft.description AND ar.activity = mft.activity
 -- Filter for the most frequent town
WHERE mft.town_rank = 1 
ORDER BY 1, 3 ASC;
    """
# Execute the query and store result
desc_act_df = query_df(query)

# Display as styled df
styled_df_by_value(desc_act_df, 'description', ['STATE_IN_SERVICE'],['STATE_OUT_OF_SERVICE'])
# Out:
# <style type="text/css">
# #T_42591_row0_col0, #T_42591_row0_col1, #T_42591_row0_col2, #T_42591_row0_col3, #T_42591_row0_col4, #T_42591_row0_col5, #T_42591_row1_col0, #T_42591_row1_col1, #T_42591_row1_col2, #T_42591_row1_col3, #T_42591_row1_col4, #T_42591_row1_col5, #T_42591_row2_col0, #T_42591_row2_col1, #T_42591_row2_col2, #T_42591_row2_col3, #T_42591_row2_col4, #T_42591_row2_col5, #T_42591_row3_col0, #T_42591_row3_col1, #T_42591_row3_col2, #T_42591_row3_col3, #T_42591_row3_col4, #T_42591_row3_col5, #T_42591_row4_col0, #T_42591_row4_col1, #T_42591_row4_col2, #T_42591_row4_col3, #T_42591_row4_col4, #T_42591_row4_col5 {
#   background-color: #9370DB;
# }
# ...
